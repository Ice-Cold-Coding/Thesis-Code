# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\SSD downloads\All Thesis Code - Final\CheXpert data exploration\Filter_Data_13_Class_CheXpert")

# %%
df['Age'].plot(kind='hist', bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["AP/PA"].unique()
# Out:
# array(['AP', 'PA'], dtype=object)

# %%
view_count = df["AP/PA"].value_counts()
print(view_count)
# Out:
# AP    21638
# PA    11356
# Name: AP/PA, dtype: int64

# %%
plt.bar(view_count.index, view_count.values)
# Out:
# <BarContainer object of 2 artists>

# %%
gender_counts = df['Sex'].value_counts()

plt.bar(gender_counts.index, gender_counts.values)

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Patient Gender Distribution')

plt.show()

# %%
place_holder_dataframe = {'Total Number': [], 'Label': []}
counting_labels = pd.DataFrame(place_holder_dataframe)

for i in df["Labels"].unique():
    new_row = {'Total Number': df[df["Labels"] == i]["Labels"].count(), 'Label': i}
    new_row_df = pd.DataFrame(new_row, index=[0])
    counting_labels = pd.concat([counting_labels, new_row_df], ignore_index=True)

# %%
counting_labels
# Out:
#     Total Number                       Label
# 0         2538.0                       Edema
# 1         8037.0                  No Finding
# 2         1692.0                Pneumothorax
# 3         4653.0             Support Devices
# 4          423.0                 Lung Lesion
# 5          846.0                    Fracture
# 6         2961.0            Pleural Effusion
# 7         1269.0                 Atelectasis
# 8         7191.0                Lung Opacity
# 9          846.0               Consolidation
# 10        1269.0                Cardiomegaly
# 11         846.0  Enlarged Cardiomediastinum
# 12         423.0                   Pneumonia

# %%
plt.pie(x = counting_labels["Total Number"],labels = counting_labels["Label"])

plt.title("CheXpert Class Distribution", fontsize=10)

plt.figure(figsize=(10,10))

plt.show()
